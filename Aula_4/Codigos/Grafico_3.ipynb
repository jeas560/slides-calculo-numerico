# %%
#Importando as bibliotecas utilizadas
from mpl_toolkits.axisartist.axislines import AxesZero
import numpy as np  #biblioteca numérica
import matplotlib.pyplot as plt

save_figures = True

fig = plt.figure()
ax = fig.add_subplot(axes_class = AxesZero)

for direction in ["left", "bottom"]:
    # adds arrows at the ends of each axis
    ax.axis[direction].set_axisline_style("-|>")

for direction in ["right", "top"]:
    # hides borders
    ax.axis[direction].set_visible(False)

x1 = np.array([1.10, 1.20])
x2 = np.linspace(1.05, 1.25, 100)
y1 = np.tan(x1)
y2 = np.tan(x2)
y3 = 1.9648 + (2.5722 - 1.9648)*(x2 - 1.1)/(1.2-1.1)

plt.plot(x2, y2, label = '$ tan (x) $')
plt.plot(x2, y3, '--', label = r'$ P_{1} (x) $')
plt.plot(x1, y1, 'ro')
plt.yticks([1.6, 2.0, 2.4, 2.8, 3.2])
plt.xticks([1.05, 1.10, 1.15, 1.20, 1.25])

plt.legend(framealpha=1, frameon = True, loc ='upper center')

ax.set_xlabel("x")
ax.set_ylabel("y")

if save_figures:
    plt.savefig('../Figuras/grafico_03.pdf')
plt.show()
